# %% [markdown]
# <a href="https://colab.research.google.com/github/ameerfayiz/ML-notebooks/blob/main/InstantID_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/InstantID-hf
# %cd /content/InstantID-hf

# !apt -y install -qq aria2
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/InstantX/InstantID/raw/main/ControlNetModel/config.json -d /content/InstantID-hf/checkpoints/ControlNetModel -o config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/InstantX/InstantID/resolve/main/ControlNetModel/diffusion_pytorch_model.safetensors -d /content/InstantID-hf/checkpoints/ControlNetModel -o diffusion_pytorch_model.safetensors
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/InstantX/InstantID/resolve/main/ip-adapter.bin -d /content/InstantID-hf/checkpoints -o ip-adapter.bin

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/InstantX/InstantID/resolve/main/models/antelopev2/1k3d68.onnx -d /content/InstantID-hf/models/antelopev2 -o 1k3d68.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/InstantX/InstantID/resolve/main/models/antelopev2/2d106det.onnx -d /content/InstantID-hf/models/antelopev2 -o 2d106det.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/InstantX/InstantID/resolve/main/models/antelopev2/genderage.onnx -d /content/InstantID-hf/models/antelopev2 -o genderage.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/InstantX/InstantID/resolve/main/models/antelopev2/glintr100.onnx -d /content/InstantID-hf/models/antelopev2 -o glintr100.onnx
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/InstantX/InstantID/resolve/main/models/antelopev2/scrfd_10g_bnkps.onnx -d /content/InstantID-hf/models/antelopev2 -o scrfd_10g_bnkps.onnx

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/InstantX/InstantID/resolve/main/examples/kaifu_resize.png -d /content/InstantID-hf/examples -o kaifu_resize.png
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/InstantX/InstantID/resolve/main/examples/sam_resize.png -d /content/InstantID-hf/examples -o sam_resize.png
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/spaces/InstantX/InstantID/resolve/main/examples/schmidhuber_resize.png -d /content/InstantID-hf/examples -o schmidhuber_resize.png

# !pip install -q insightface onnxruntime diffusers accelerate gradio==4.15.0
# !pip install -q https://download.pytorch.org/whl/cu121/xformers-0.0.22.post7-cp310-cp310-manylinux2014_x86_64.whl
# !pip install diffusers==0.26.3
# Out:
# /content
# Cloning into 'InstantID-hf'...
# remote: Enumerating objects: 72, done.
# remote: Counting objects: 100% (72/72), done.
# remote: Compressing objects: 100% (46/46), done.
# remote: Total 72 (delta 28), reused 67 (delta 24), pack-reused 0
# Receiving objects: 100% (72/72), 415.88 KiB | 2.18 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# Downloading examples/kaifu_resize.png (1.1 MB)
# Error downloading object: examples/kaifu_resize.png (b7302f0): Smudge error: Error downloading examples/kaifu_resize.png (b7302f0f7d0ff61be67bf13d172ad2393b6cb2bc985f048089f4e901145324d7): [b7302f0f7d0ff61be67bf13d172ad2393b6cb2bc985f048089f4e901145324d7] Object does not exist on the server: [404] Object does not exist on the server
#
# Errors logged to /content/InstantID-hf/.git/lfs/logs/20240321T061425.500929571.log
# Use `git lfs logs last` to view the log.
# error: external filter 'git-lfs filter-process' failed
# fatal: examples/kaifu_resize.png: smudge filter lfs failed
# warning: Clone succeeded, but checkout failed.
# You can inspect what was checked out with 'git status'
# and retry with 'git restore --source=HEAD :/'
#
# /content/InstantID-hf
# The following additional packages will be installed:
#   libaria2-0 libc-ares2
# The following NEW packages will be installed:
#   aria2 libaria2-0 libc-ares2
# 0 upgraded, 3 newly installed, 0 to remove and 39 not upgraded.
# Need to get 1,513 kB of archives.
# After this operation, 5,441 kB of additional disk space will be used.
# Selecting previously unselected package libc-ares2:amd64.
# (Reading database ... 121752 files and directories currently installed.)
# Preparing to unpack .../libc-ares2_1.18.1-1ubuntu0.22.04.3_amd64.deb ...
# Unpacking libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Selecting previously unselected package libaria2-0:amd64.
# Preparing to unpack .../libaria2-0_1.36.0-1_amd64.deb ...
# Unpacking libaria2-0:amd64 (1.36.0-1) ...
# Selecting previously unselected package aria2.
# Preparing to unpack .../aria2_1.36.0-1_amd64.deb ...
# Unpacking aria2 (1.36.0-1) ...
# Setting up libc-ares2:amd64 (1.18.1-1ubuntu0.22.04.3) ...
# Setting up libaria2-0:amd64 (1.36.0-1) ...
# Setting up aria2 (1.36.0-1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.4) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 702f40|OK  |   167KiB/s|/content/InstantID-hf/checkpoints/ControlNetModel/config.json
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 2d8c30|OK  |   164MiB/s|/content/InstantID-hf/checkpoints/ControlNetModel/diffusion_pytorch_model.safetensors
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 3918ed|OK  |   256MiB/s|/content/InstantID-hf/checkpoints/ip-adapter.bin
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# db5fe8|OK  |   207MiB/s|/content/InstantID-hf/models/antelopev2/1k3d68.onnx
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 0f55e1|OK  |    76MiB/s|/content/InstantID-hf/models/antelopev2/2d106det.onnx
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 042045|OK  |    26MiB/s|/content/InstantID-hf/models/antelopev2/genderage.onnx
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 027837|OK  |   240MiB/s|/content/InstantID-hf/models/antelopev2/glintr100.onnx
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# a9b4b9|OK  |    98MiB/s|/content/InstantID-hf/models/antelopev2/scrfd_10g_bnkps.onnx
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 39dee3|OK  |    21MiB/s|/content/InstantID-hf/examples/kaifu_resize.png
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 8e1c6b|OK  |    40MiB/s|/content/InstantID-hf/examples/sam_resize.png
#
# Status Legend:
# (OK):download completed.
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# 106569|OK  |    50MiB/s|/content/InstantID-hf/examples/schmidhuber_resize.png
#
# Status Legend:
# (OK):download completed.
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.5/439.5 kB 9.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 29.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 49.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 290.1/290.1 kB 32.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 73.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.1/92.1 kB 12.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 305.2/305.2 kB 35.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.6/75.6 kB 10.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 18.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 97.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 17.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 82.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 6.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 21.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 73.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 95.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 7.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 13.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 51.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 13.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 11.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.8/77.8 kB 11.2 MB/s eta 0:00:00
#   Building wheel for insightface (pyproject.toml) ... done
#   Building wheel for ffmpy (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.8/211.8 MB 6.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 5.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 9.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.2.1+cu121 requires torch==2.2.1, but you have torch 2.1.0 which is incompatible.
# torchtext 0.17.1 requires torch==2.2.1, but you have torch 2.1.0 which is incompatible.
# torchvision 0.17.1+cu121 requires torch==2.2.1, but you have torch 2.1.0 which is incompatible.
# The cache for model files in Transformers v4.22.0 has been updated. Migrating your old cache. This is a one-time only operation. You can interrupt this and resume the migration later on by calling `transformers.utils.move_cache()`.
# 0it [00:00, ?it/s]
# 2024-03-21 06:18:39.610800: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-21 06:18:39.610904: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-21 06:18:39.726630: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-21 06:18:42.032012: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:69: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: ./models/antelopev2/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: ./models/antelopev2/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: ./models/antelopev2/genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: ./models/antelopev2/glintr100.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: ./models/antelopev2/scrfd_10g_bnkps.onnx detection [1, 3, '?', '?'] 127.5 128.0
# set det-size: (640, 640)
# model_index.json: 100% 800/800 [00:00<00:00, 5.03MB/s]
# Fetching 18 files:   0% 0/18 [00:00<?, ?it/s]
# text_encoder/config.json: 100% 676/676 [00:00<00:00, 2.97MB/s]
#
# tokenizer/tokenizer_config.json: 100% 737/737 [00:00<00:00, 5.19MB/s]
#
# tokenizer/special_tokens_map.json: 100% 472/472 [00:00<00:00, 3.86MB/s]
#
# scheduler/scheduler_config.json: 100% 474/474 [00:00<00:00, 3.09MB/s]
# Fetching 18 files:  11% 2/18 [00:00<00:04,  3.68it/s]
# tokenizer/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
# tokenizer/merges.txt:   0% 0.00/525k [00:00<?, ?B/s]
#
#
# text_encoder_2/config.json: 100% 688/688 [00:00<00:00, 3.84MB/s]
#
#
#
# tokenizer_2/special_tokens_map.json: 100% 460/460 [00:00<00:00, 3.38MB/s]
#
#
#
# model.safetensors:   0% 0.00/1.39G [00:00<?, ?B/s]
#
#
#
# tokenizer_2/tokenizer_config.json: 100% 725/725 [00:00<00:00, 4.08MB/s]
#
#
#
#
# model.safetensors:   0% 0.00/246M [00:00<?, ?B/s]
#
# tokenizer/merges.txt: 100% 525k/525k [00:00<00:00, 2.59MB/s]
#
# tokenizer/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 3.97MB/s]
#
# unet/config.json: 100% 1.83k/1.83k [00:00<00:00, 8.62MB/s]
#
# tokenizer_2/merges.txt:   0% 0.00/525k [00:00<?, ?B/s]
#
#
#
# model.safetensors:   4% 10.5M/246M [00:00<00:03, 61.8MB/s]
#
#
# model.safetensors:   1% 10.5M/1.39G [00:00<00:31, 44.0MB/s]
#
# tokenizer_2/vocab.json:   0% 0.00/1.06M [00:00<?, ?B/s]
#
#
#
#
# vae/config.json: 100% 709/709 [00:00<00:00, 2.35MB/s]
#
#
#
#
#
# diffusion_pytorch_model.safetensors:   0% 0.00/5.14G [00:00<?, ?B/s]
#
#
#
# model.safetensors:   9% 21.0M/246M [00:00<00:02, 76.5MB/s]
#
#
# model.safetensors:   2% 21.0M/1.39G [00:00<00:23, 57.7MB/s]
# tokenizer_2/merges.txt: 100% 525k/525k [00:00<00:00, 2.64MB/s]
#
#
# tokenizer_2/vocab.json: 100% 1.06M/1.06M [00:00<00:00, 5.59MB/s]
#
#
#
#
# model.safetensors:  13% 31.5M/246M [00:00<00:02, 85.6MB/s]
# diffusion_pytorch_model.safetensors:   0% 0.00/167M [00:00<?, ?B/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   0% 10.5M/5.14G [00:00<01:18, 65.2MB/s]
#
#
# model.safetensors:   2% 31.5M/1.39G [00:00<00:19, 68.6MB/s]
# diffusion_pytorch_model.safetensors:   6% 10.5M/167M [00:00<00:02, 76.9MB/s]
#
#
# model.safetensors:   3% 41.9M/1.39G [00:00<00:17, 75.9MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   0% 21.0M/5.14G [00:00<01:13, 69.4MB/s]
#
#
#
# model.safetensors:  21% 52.4M/246M [00:00<00:02, 91.6MB/s]
# diffusion_pytorch_model.safetensors:  13% 21.0M/167M [00:00<00:02, 71.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   1% 31.5M/5.14G [00:00<01:08, 74.2MB/s]
#
#
# model.safetensors:   4% 52.4M/1.39G [00:00<00:17, 75.6MB/s]
#
#
#
# model.safetensors:  26% 62.9M/246M [00:00<00:02, 84.9MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   1% 41.9M/5.14G [00:00<01:00, 83.7MB/s]
# diffusion_pytorch_model.safetensors:  19% 31.5M/167M [00:00<00:01, 69.1MB/s]
#
#
# model.safetensors:   5% 62.9M/1.39G [00:00<00:17, 74.2MB/s]
#
#
#
# model.safetensors:  30% 73.4M/246M [00:00<00:01, 86.5MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   1% 52.4M/5.14G [00:00<00:59, 85.8MB/s]
#
#
# model.safetensors:   5% 73.4M/1.39G [00:01<00:16, 79.1MB/s]
#
#
#
# model.safetensors:  34% 83.9M/246M [00:00<00:01, 84.9MB/s]
# diffusion_pytorch_model.safetensors:  31% 52.4M/167M [00:00<00:01, 87.6MB/s]
#
#
#
# model.safetensors:  38% 94.4M/246M [00:01<00:01, 85.2MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   1% 73.4M/5.14G [00:00<00:55, 91.6MB/s]
#
#
# model.safetensors:   7% 94.4M/1.39G [00:01<00:14, 90.5MB/s]
# diffusion_pytorch_model.safetensors:  44% 73.4M/167M [00:00<00:00, 96.1MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   2% 94.4M/5.14G [00:01<00:47, 106MB/s]
#
#
#
# model.safetensors:  47% 115M/246M [00:01<00:01, 95.6MB/s]
#
#
# model.safetensors:   8% 115M/1.39G [00:01<00:12, 99.7MB/s]
# diffusion_pytorch_model.safetensors:  56% 94.4M/167M [00:00<00:00, 106MB/s]
#
#
# model.safetensors:   9% 126M/1.39G [00:01<00:12, 99.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   2% 115M/5.14G [00:01<00:49, 101MB/s]
#
#
#
# model.safetensors:  55% 136M/246M [00:01<00:01, 92.4MB/s]
#
#
# model.safetensors:  10% 136M/1.39G [00:01<00:14, 83.7MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   2% 126M/5.14G [00:01<00:58, 85.0MB/s]
#
#
#
# model.safetensors:  60% 147M/246M [00:01<00:01, 80.6MB/s]
# diffusion_pytorch_model.safetensors:  69% 115M/167M [00:02<00:01, 29.4MB/s]
#
#
# model.safetensors:  11% 147M/1.39G [00:04<01:23, 14.9MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   3% 136M/5.14G [00:05<08:02, 10.4MB/s]
# diffusion_pytorch_model.safetensors:  75% 126M/167M [00:05<00:03, 11.8MB/s]
#
#
# model.safetensors:  11% 157M/1.39G [00:06<02:05, 9.85MB/s]
#
#
#
# model.safetensors:  64% 157M/246M [00:06<00:09, 9.19MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   3% 147M/5.14G [00:05<06:55, 12.0MB/s]
# diffusion_pytorch_model.safetensors:  81% 136M/167M [00:05<00:02, 13.8MB/s]
#
#
#
# model.safetensors:  68% 168M/246M [00:06<00:06, 11.3MB/s]
#
#
# model.safetensors:  12% 168M/1.39G [00:06<01:41, 12.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   3% 157M/5.14G [00:06<05:47, 14.3MB/s]
#
#
# model.safetensors:  13% 178M/1.39G [00:06<01:17, 15.7MB/s]
# diffusion_pytorch_model.safetensors:  88% 147M/167M [00:06<00:01, 16.4MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   3% 168M/5.14G [00:06<04:29, 18.4MB/s]
#
#
#
# model.safetensors:  72% 178M/246M [00:06<00:04, 14.1MB/s]
#
#
# model.safetensors:  14% 189M/1.39G [00:06<00:59, 20.3MB/s]
#
#
#
# model.safetensors:  77% 189M/246M [00:06<00:03, 18.5MB/s]
# diffusion_pytorch_model.safetensors:  94% 157M/167M [00:06<00:00, 20.1MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   3% 178M/5.14G [00:06<03:42, 22.2MB/s]
#
#
# model.safetensors:  14% 199M/1.39G [00:06<00:45, 26.4MB/s]
# diffusion_pytorch_model.safetensors: 100% 167M/167M [00:06<00:00, 25.4MB/s]
#
#
#
#
# model.safetensors:  81% 199M/246M [00:07<00:02, 21.4MB/s]
#
#
# model.safetensors:  15% 210M/1.39G [00:07<00:38, 30.4MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   4% 189M/5.14G [00:06<03:15, 25.3MB/s]
#
#
#
# model.safetensors:  85% 210M/246M [00:07<00:01, 26.8MB/s]
#
#
# model.safetensors:  16% 220M/1.39G [00:07<00:32, 35.6MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   4% 199M/5.14G [00:06<02:40, 30.7MB/s]
#
#
#
# model.safetensors:  89% 220M/246M [00:07<00:00, 33.6MB/s]
#
#
#
# model.safetensors:  94% 231M/246M [00:07<00:00, 41.4MB/s]
#
#
# model.safetensors:  17% 231M/1.39G [00:07<00:29, 39.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   4% 220M/5.14G [00:07<01:51, 44.0MB/s]
#
#
#
# model.safetensors:  98% 241M/246M [00:07<00:00, 47.8MB/s]
#
#
# model.safetensors:  17% 241M/1.39G [00:07<00:24, 46.2MB/s]
#
#
#
#
# model.safetensors: 100% 246M/246M [00:07<00:00, 32.0MB/s]
#
#
#
# Fetching 18 files:  22% 4/18 [00:08<00:34,  2.44s/it]
#
#
#
#
# diffusion_pytorch_model.safetensors:   5% 241M/5.14G [00:07<01:28, 55.2MB/s]
#
#
# model.safetensors:  20% 273M/1.39G [00:07<00:15, 72.9MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   5% 262M/5.14G [00:07<01:07, 72.0MB/s]
#
#
# model.safetensors:  21% 294M/1.39G [00:08<00:12, 87.1MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   6% 283M/5.14G [00:07<00:58, 82.7MB/s]
#
#
# model.safetensors:  23% 315M/1.39G [00:08<00:10, 98.4MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   6% 294M/5.14G [00:07<00:56, 85.8MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   6% 304M/5.14G [00:08<00:54, 88.6MB/s]
#
#
# model.safetensors:  24% 336M/1.39G [00:08<00:10, 101MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   6% 325M/5.14G [00:08<00:48, 99.3MB/s]
#
#
# model.safetensors:  26% 357M/1.39G [00:08<00:09, 106MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   7% 336M/5.14G [00:08<00:47, 100MB/s]
#
#
# model.safetensors:  27% 377M/1.39G [00:08<00:09, 111MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   7% 357M/5.14G [00:08<00:42, 111MB/s]
#
#
# model.safetensors:  29% 398M/1.39G [00:08<00:08, 114MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   7% 377M/5.14G [00:08<00:42, 113MB/s]
#
#
# model.safetensors:  30% 419M/1.39G [00:09<00:08, 115MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   8% 398M/5.14G [00:08<00:42, 112MB/s]
#
#
# model.safetensors:  32% 440M/1.39G [00:09<00:07, 126MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   8% 419M/5.14G [00:08<00:38, 124MB/s]
#
#
# model.safetensors:  33% 461M/1.39G [00:09<00:07, 130MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   9% 440M/5.14G [00:09<00:39, 119MB/s]
#
#
# model.safetensors:  35% 482M/1.39G [00:09<00:07, 122MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   9% 461M/5.14G [00:09<00:39, 118MB/s]
#
#
# model.safetensors:  36% 503M/1.39G [00:09<00:06, 128MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:   9% 482M/5.14G [00:09<00:36, 126MB/s]
#
#
# model.safetensors:  38% 524M/1.39G [00:09<00:06, 130MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  10% 503M/5.14G [00:09<00:37, 125MB/s]
#
#
# model.safetensors:  39% 545M/1.39G [00:10<00:07, 117MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  10% 524M/5.14G [00:09<00:39, 116MB/s]
#
#
# model.safetensors:  41% 566M/1.39G [00:10<00:07, 105MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  11% 545M/5.14G [00:10<00:43, 106MB/s]
#
#
# model.safetensors:  42% 587M/1.39G [00:11<00:22, 35.7MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  11% 566M/5.14G [00:11<02:09, 35.3MB/s]
#
#
# model.safetensors:  43% 598M/1.39G [00:13<00:34, 22.7MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  11% 577M/5.14G [00:12<03:24, 22.3MB/s]
#
#
# model.safetensors:  45% 619M/1.39G [00:13<00:24, 31.5MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  11% 587M/5.14G [00:12<02:51, 26.5MB/s]
#
#
# model.safetensors:  46% 640M/1.39G [00:13<00:17, 42.7MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  12% 608M/5.14G [00:13<01:59, 37.9MB/s]
#
#
# model.safetensors:  48% 661M/1.39G [00:13<00:14, 51.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  12% 629M/5.14G [00:13<01:33, 48.3MB/s]
#
#
# model.safetensors:  49% 682M/1.39G [00:13<00:10, 64.5MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  13% 650M/5.14G [00:13<01:12, 61.6MB/s]
#
#
# model.safetensors:  51% 703M/1.39G [00:13<00:08, 78.8MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  13% 671M/5.14G [00:13<00:58, 76.5MB/s]
#
#
# model.safetensors:  52% 724M/1.39G [00:14<00:07, 91.8MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  13% 692M/5.14G [00:13<00:48, 90.8MB/s]
#
#
# model.safetensors:  54% 744M/1.39G [00:14<00:06, 103MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  14% 713M/5.14G [00:13<00:43, 102MB/s]
#
#
# model.safetensors:  55% 765M/1.39G [00:14<00:05, 116MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  14% 734M/5.14G [00:14<00:38, 114MB/s]
#
#
# model.safetensors:  57% 786M/1.39G [00:14<00:04, 131MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  15% 755M/5.14G [00:14<00:36, 119MB/s]
#
#
# model.safetensors:  58% 807M/1.39G [00:14<00:04, 131MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  15% 776M/5.14G [00:14<00:35, 124MB/s]
#
#
# model.safetensors:  60% 828M/1.39G [00:14<00:03, 141MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  16% 797M/5.14G [00:14<00:31, 138MB/s]
#
#
# model.safetensors:  62% 860M/1.39G [00:14<00:03, 166MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  16% 818M/5.14G [00:14<00:28, 150MB/s]
#
#
# model.safetensors:  63% 881M/1.39G [00:15<00:04, 114MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  16% 839M/5.14G [00:14<00:42, 100MB/s]
#
#
# model.safetensors:  65% 902M/1.39G [00:15<00:05, 95.0MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  17% 860M/5.14G [00:15<00:47, 89.9MB/s]
#
#
# model.safetensors:  66% 923M/1.39G [00:15<00:04, 94.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  17% 881M/5.14G [00:15<00:47, 89.3MB/s]
#
#
# model.safetensors:  68% 944M/1.39G [00:15<00:04, 103MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  18% 902M/5.14G [00:15<00:42, 99.5MB/s]
#
#
# model.safetensors:  69% 965M/1.39G [00:16<00:03, 113MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  18% 923M/5.14G [00:15<00:36, 114MB/s]
#
#
# model.safetensors:  71% 986M/1.39G [00:16<00:03, 118MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  18% 944M/5.14G [00:15<00:35, 118MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  19% 965M/5.14G [00:16<01:27, 47.7MB/s]
#
#
# model.safetensors:  72% 1.01G/1.39G [00:17<00:08, 46.8MB/s]
#
#
# model.safetensors:  75% 1.04G/1.39G [00:17<00:05, 67.9MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  19% 996M/5.14G [00:17<01:00, 68.5MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  20% 1.02G/5.14G [00:17<00:50, 81.6MB/s]
#
#
# model.safetensors:  77% 1.07G/1.39G [00:17<00:03, 90.2MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  20% 1.04G/5.14G [00:17<00:45, 89.5MB/s]
#
#
# model.safetensors:  78% 1.09G/1.39G [00:17<00:03, 96.2MB/s]
#
#
# model.safetensors:  80% 1.11G/1.39G [00:17<00:02, 106MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  21% 1.06G/5.14G [00:17<00:43, 93.2MB/s]
#
#
# model.safetensors:  82% 1.13G/1.39G [00:18<00:02, 109MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  21% 1.08G/5.14G [00:17<00:38, 104MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  21% 1.10G/5.14G [00:17<00:34, 116MB/s]
#
#
# model.safetensors:  83% 1.15G/1.39G [00:18<00:02, 115MB/s]
#
#
# model.safetensors:  85% 1.17G/1.39G [00:18<00:01, 124MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  22% 1.12G/5.14G [00:18<00:33, 119MB/s]
#
#
# model.safetensors:  86% 1.20G/1.39G [00:18<00:01, 131MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  22% 1.14G/5.14G [00:18<00:31, 127MB/s]
#
#
# model.safetensors:  88% 1.22G/1.39G [00:18<00:01, 134MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  23% 1.16G/5.14G [00:18<00:31, 127MB/s]
#
#
# model.safetensors:  89% 1.24G/1.39G [00:18<00:01, 139MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  23% 1.18G/5.14G [00:18<00:29, 133MB/s]
#
#
# model.safetensors:  91% 1.26G/1.39G [00:18<00:00, 145MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  23% 1.21G/5.14G [00:18<00:29, 134MB/s]
#
#
# model.safetensors:  92% 1.28G/1.39G [00:19<00:00, 144MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  24% 1.23G/5.14G [00:18<00:28, 137MB/s]
#
#
# model.safetensors:  94% 1.30G/1.39G [00:19<00:00, 153MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  24% 1.25G/5.14G [00:18<00:28, 137MB/s]
#
#
# model.safetensors:  95% 1.32G/1.39G [00:19<00:00, 162MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  25% 1.27G/5.14G [00:19<00:29, 132MB/s]
#
#
# model.safetensors:  97% 1.34G/1.39G [00:19<00:00, 151MB/s]
#
#
# model.safetensors:  98% 1.36G/1.39G [00:19<00:00, 153MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  25% 1.29G/5.14G [00:19<00:28, 135MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  26% 1.31G/5.14G [00:19<00:26, 144MB/s]
#
#
# model.safetensors: 100% 1.39G/1.39G [00:19<00:00, 70.3MB/s]
# Fetching 18 files:  33% 6/18 [00:20<00:48,  4.07s/it]
#
#
#
#
# diffusion_pytorch_model.safetensors:  26% 1.33G/5.14G [00:19<00:25, 148MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  27% 1.36G/5.14G [00:19<00:21, 172MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  27% 1.38G/5.14G [00:19<00:21, 174MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  28% 1.42G/5.14G [00:19<00:19, 189MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  28% 1.44G/5.14G [00:20<00:19, 193MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  29% 1.47G/5.14G [00:20<00:18, 199MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  29% 1.50G/5.14G [00:20<00:17, 206MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  30% 1.52G/5.14G [00:20<00:18, 199MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  30% 1.54G/5.14G [00:20<00:18, 196MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  30% 1.56G/5.14G [00:20<00:18, 192MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  31% 1.58G/5.14G [00:20<00:18, 189MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  31% 1.60G/5.14G [00:20<00:19, 183MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  32% 1.63G/5.14G [00:21<00:19, 180MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  32% 1.65G/5.14G [00:21<00:18, 185MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  32% 1.67G/5.14G [00:21<00:18, 184MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  33% 1.69G/5.14G [00:21<00:28, 123MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  33% 1.72G/5.14G [00:21<00:23, 148MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  34% 1.75G/5.14G [00:21<00:20, 168MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  35% 1.77G/5.14G [00:21<00:19, 171MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  35% 1.79G/5.14G [00:22<00:23, 140MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  35% 1.81G/5.14G [00:22<00:31, 105MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  36% 1.84G/5.14G [00:22<00:32, 103MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  36% 1.86G/5.14G [00:23<00:37, 88.5MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  37% 1.88G/5.14G [00:23<00:36, 90.2MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  37% 1.89G/5.14G [00:23<00:39, 82.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  37% 1.91G/5.14G [00:23<00:37, 85.2MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  38% 1.93G/5.14G [00:23<00:33, 96.1MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  38% 1.94G/5.14G [00:23<00:36, 88.4MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  38% 1.96G/5.14G [00:24<00:36, 88.1MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:
B/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  94% 4.80G/5.14G [00:48<00:01, 197MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  94% 4.82G/5.14G [00:49<00:01, 196MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  94% 4.84G/5.14G [00:49<00:01, 192MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  95% 4.87G/5.14G [00:49<00:01, 148MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  95% 4.89G/5.14G [00:49<00:02, 93.9MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  96% 4.91G/5.14G [00:49<00:02, 103MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  96% 4.93G/5.14G [00:52<00:07, 27.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  96% 4.95G/5.14G [00:52<00:05, 35.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  97% 4.97G/5.14G [00:52<00:03, 44.7MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  97% 4.99G/5.14G [00:52<00:02, 52.2MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  97% 5.00G/5.14G [00:52<00:02, 55.9MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  98% 5.02G/5.14G [00:53<00:01, 65.7MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  98% 5.04G/5.14G [00:53<00:01, 75.3MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  98% 5.05G/5.14G [00:53<00:01, 77.8MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  99% 5.08G/5.14G [00:53<00:00, 80.5MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  99% 5.10G/5.14G [00:53<00:00, 91.7MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors:  99% 5.11G/5.14G [00:53<00:00, 85.7MB/s]
#
#
#
#
# diffusion_pytorch_model.safetensors: 100% 5.14G/5.14G [00:54<00:00, 94.9MB/s]
# Fetching 18 files: 100% 18/18 [00:55<00:00,  3.06s/it]
# The config attributes {'controlnet_list': ['controlnet', 'RPMultiControlNetModel'], 'requires_aesthetics_score': False} were passed to StableDiffusionXLInstantIDPipeline, but are not expected and will be ignored. Please verify your model_index.json configuration file.
# Keyword arguments {'controlnet_list': ['controlnet', 'RPMultiControlNetModel'], 'requires_aesthetics_score': False, 'safety_checker': None} are not expected by StableDiffusionXLInstantIDPipeline and will be ignored.
# Loading pipeline components...: 100% 7/7 [00:03<00:00,  2.16it/s]
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://b79821868e898f7d95.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# /usr/local/lib/python3.10/dist-packages/insightface/utils/transform.py:68: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   P = np.linalg.lstsq(X_homo, Y)[0].T # Affine matrix. 3 x 4
# Start inference...
# [Debug] Prompt: person with blue cloths,
# [Debug] Neg Prompt:  (lowres, low quality, worst quality:1.2), (text:1.2), watermark, (frame:1.2), deformed, ugly, deformed eyes, blur, out of focus, blurry, deformed cat, deformed, photo, anthropomorphic cat, monochrome, pet collar, gun, weapon, blue, 3d, drones, drone, buildings in background, green
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/gradio/queueing.py", line 495, in call_prediction
#     output = await route_utils.call_process_api(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/route_utils.py", line 232, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1561, in process_api
#     result = await self.call_function(
#   File "/usr/local/lib/python3.10/dist-packages/gradio/blocks.py", line 1179, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/to_thread.py", line 33, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 877, in run_sync_in_worker_thread
#     return await future
#   File "/usr/local/lib/python3.10/dist-packages/anyio/_backends/_asyncio.py", line 807, in run
#     result = context.run(func, *args)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 678, in wrapper
#     response = f(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/gradio/utils.py", line 678, in wrapper
#     response = f(*args, **kwargs)
#   File "/content/InstantID-hf/app.py", line 227, in generate_image
#     images = pipe(
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 115, in decorate_context
#     return func(*args, **kwargs)
#   File "/content/InstantID-hf/pipeline_stable_diffusion_xl_instantid.py", line 794, in __call__
#     self.check_inputs(
#   File "/usr/local/lib/python3.10/dist-packages/diffusers/pipelines/controlnet/pipeline_controlnet_sd_xl.py", line 684, in check_inputs
#     raise TypeError("For single controlnet: `controlnet_conditioning_scale` must be type `float`.")
# TypeError: For single controlnet: `controlnet_conditioning_scale` must be type `float`.
# Keyboard interruption in main thread... closing server.
# Killing tunnel 127.0.0.1:7860 <> https://b79821868e898f7d95.gradio.live

# %%
# !python app.py
# Out:
# 2024-03-21 06:25:44.878601: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-21 06:25:44.878658: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-21 06:25:44.885004: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-21 06:25:47.167019: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /usr/local/lib/python3.10/dist-packages/onnxruntime/capi/onnxruntime_inference_collection.py:69: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: ./models/antelopev2/1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: ./models/antelopev2/2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: ./models/antelopev2/genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: ./models/antelopev2/glintr100.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: ./models/antelopev2/scrfd_10g_bnkps.onnx detection [1, 3, '?', '?'] 127.5 128.0
# set det-size: (640, 640)
# The config attributes {'controlnet_list': ['controlnet', 'RPMultiControlNetModel'], 'requires_aesthetics_score': False} were passed to StableDiffusionXLInstantIDPipeline, but are not expected and will be ignored. Please verify your model_index.json configuration file.
# Keyword arguments {'controlnet_list': ['controlnet', 'RPMultiControlNetModel'], 'requires_aesthetics_score': False, 'safety_checker': None} are not expected by StableDiffusionXLInstantIDPipeline and will be ignored.
# Loading pipeline components...: 100% 7/7 [00:02<00:00,  3.29it/s]
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://16ae60dc41070b6ec9.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
