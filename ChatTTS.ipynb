# %% [markdown]
# <a href="https://colab.research.google.com/github/ameerfayiz/ML-notebooks/blob/main/ChatTTS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ameerfayiz/ChatTTS.git
# Out:
# Cloning into 'ChatTTS'...
# remote: Enumerating objects: 168, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (79/79), done.
# remote: Total 168 (delta 92), reused 51 (delta 51), pack-reused 38
# Receiving objects: 100% (168/168), 2.73 MiB | 1.50 MiB/s, done.
# Resolving deltas: 100% (93/93), done.

# %%
# !pip install omegaconf~=2.3.0 -q
# !pip install einops -q
# !pip install vector_quantize_pytorch -q
# !pip install vocos -q
# !pip install IPython -q
# !pip install nemo_text_processing  -q
# !pip install pynini -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 3.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.0/117.0 kB 12.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for antlr4-python3-runtime (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 1.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.6/101.6 kB 6.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 50.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.7/3.7 MB 51.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for encodec (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 26.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 38.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.3/161.3 MB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 897.5/897.5 kB 66.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for cdifflib (pyproject.toml) ... done
#   Building wheel for wget (setup.py) ... done

# %%
# !pip install gradio
# !python webui.py

# %%
from ChatTTS import ChatTTS
from IPython.display import Audio

chat = ChatTTS.Chat()
chat.load_models(compile=True) # Set to True for better performance
# torchaudio.save("output1.wav", torch.from_numpy(wavs[0]), 24000)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 11 files:   0%|          | 0/11 [00:00<?, ?it/s]
# Decoder.pt:   0%|          | 0.00/104M [00:00<?, ?B/s]
# config/decoder.yaml:   0%|          | 0.00/117 [00:00<?, ?B/s]
# config/dvae.yaml:   0%|          | 0.00/143 [00:00<?, ?B/s]
# DVAE.pt:   0%|          | 0.00/27.7M [00:00<?, ?B/s]
# spk_stat.pt:   0%|          | 0.00/4.26k [00:00<?, ?B/s]
# Vocos.pt:   0%|          | 0.00/54.4M [00:00<?, ?B/s]
# tokenizer.pt:   0%|          | 0.00/337k [00:00<?, ?B/s]
# GPT.pt:   0%|          | 0.00/901M [00:00<?, ?B/s]
# config/path.yaml:   0%|          | 0.00/309 [00:00<?, ?B/s]
# config/gpt.yaml:   0%|          | 0.00/346 [00:00<?, ?B/s]
# config/vocos.yaml:   0%|          | 0.00/460 [00:00<?, ?B/s]
#  NeMo-text-processing :: INFO     :: Creating ClassifyFst grammars.
# INFO:NeMo-text-processing:Creating ClassifyFst grammars.
#   4%|▍         | 17/384 [02:30<54:08,  8.85s/it]
#   6%|▌         | 114/2048 [00:01<00:28, 68.94it/s]
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
texts = ["hey buddyy. i am soo happy today, huh, are you happy?? now [laugh_7]",]

wavs = chat.infer(texts, )

Audio(wavs[0], rate=24_000, autoplay=True)
# Out:
# WARNING:ChatTTS.ChatTTS.core:Invalid characters found! : {'[', '7', '_', '?', ']'}
#  10%|▉         | 38/384 [00:00<00:04, 78.25it/s]
#  16%|█▋        | 334/2048 [00:05<00:27, 61.31it/s]
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
params_infer_code = {'prompt':'[speed_5]', 'temperature':.3}
params_refine_text = {'prompt':'[oral_2][laugh_0][break_6]'}

texts = ["I think programmers like us may have some feelings about open source. I think open source is a good form. Now the most advanced technology is in the hands of some companies, and they will not easily open it to everyone."]

wavs = chat.infer(texts, params_refine_text=params_refine_text, params_infer_code=params_infer_code)

Audio(wavs[0], rate=24_000, autoplay=True)
# Out:
#  16%|█▋        | 63/384 [00:48<04:04,  1.31it/s]
#  32%|███▏      | 660/2048 [00:08<00:18, 76.21it/s]
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
rand_spk = chat.sample_random_speaker()
params_infer_code = {'spk_emb' : rand_spk, }
params_refine_text = {'prompt':'[oral_2][laugh_0][break_6]'}

texts = ["I think programmers like us may have some feelings about open source. I think open source is a good form. Now the most advanced technology is in the hands of some companies, and they will not easily open it to everyone."]


wavs = chat.infer(texts, params_refine_text=params_refine_text, params_infer_code=params_infer_code)

Audio(wavs[0], rate=24_000, autoplay=True)
# Out:
#  16%|█▌        | 62/384 [00:00<00:04, 77.13it/s]
#  34%|███▍      | 704/2048 [00:08<00:16, 80.29it/s]
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
text = "So we found being competitive and collaborative was a huge way of staying motivated towards our goals, so one person to call when you fall off, one person who gets you back on then one person to actually do the activity with."
refined_text = chat.infer(text, refine_text_only=True)
print(refined_text)
wavs = chat.infer(refined_text, skip_refine_text=True)
Audio(wavs[0], rate=24_000, autoplay=True)
# Out:
#  21%|██▏       | 82/384 [00:01<00:05, 54.65it/s]
# ['so we found being competitive [uv_break] and [uv_break] collaborative was a huge way [uv_break] of staying motivated towards our goals, [uv_break] so one person to call when you fall off, [uv_break] one person who gets you back on then one person to actually do the activity with.']
#  46%|████▌     | 946/2048 [00:12<00:14, 74.29it/s]
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
